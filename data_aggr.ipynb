# %%
import pandas as pd
import numpy as np

# %%
bus1 = pd.read_csv("data/business.csv")
bus2 = pd.read_csv("data/business2.csv")
cul1 = pd.read_csv("data/culture.csv")
cul2 = pd.read_csv("data/culture2.csv")
evnt1 = pd.read_csv("data/event.csv")
evnt2 = pd.read_csv("data/event2.csv")
evnt3 = pd.read_csv("data/event3.csv")
evnt4 = pd.read_csv("data/event4.csv")
evnt5 = pd.read_csv("data/event5.csv")
evnt6 = pd.read_csv("data/event6.csv")
evnt7 = pd.read_csv("data/event7.csv")
evnt8 = pd.read_csv("data/event8.csv")
evnt9 = pd.read_csv("data/event9.csv")
evnt10 = pd.read_csv("data/event10.csv")
evnt11 = pd.read_csv("data/event11.csv")
evnt12 = pd.read_csv("data/event12.csv")
evnt13 = pd.read_csv("data/event13.csv")
law = pd.read_csv("data/law.csv")
politics = pd.read_csv("data/politics.csv")
press1 = pd.read_csv("data/pressdigest.csv")
press2 = pd.read_csv("data/pressdigest2.csv")
sport1 = pd.read_csv("data/sport.csv")
sport2 = pd.read_csv("data/sport2.csv")
sport3 = pd.read_csv("data/sport3.csv")
sport4 = pd.read_csv("data/sport4.csv")
sport5 = pd.read_csv("data/sport5.csv")
sport6 = pd.read_csv("data/sport6.csv")
other = pd.read_csv("data/other.csv")

# %%
business = pd.concat([bus1, bus2], axis=0)
business["category"] = 0
business
# Out:
#                                                    title                 date  \
# 0      «Գազպրոմը» 2021 թվականին ռեկորդային ծավալով գա...  2021-09-20 18:52:00
# 1      «Հայաստան 2020» ծրագրի նախաձեռնողները ներկայաց...  2021-09-20 19:26:00
# 2      Երևանում կասեցվել է հացի արտադրամասի գործունեո...  2021-09-13 12:06:00
# 3             Եվրոպայում գազի գինը նոր ռեկորդ է սահմանել  2021-09-13 12:11:00
# 4      Ալյումինի գինը նվազել է, պղնձի գինն` աճել. գու...  2021-09-04 11:05:00
# ...                                                  ...                  ...
# 16347                Քլինթոնները շարունակում է հարստանալ  2008-04-05 14:27:00
# 16348  Ոսկու շուկան դեռևս մեկ անգամ չէ, որ հաճելիորեն...  2008-04-05 15:56:00
# 16349  Ֆրանսիական Le Monde-ի լրագրողները գործադուլ կհ...  2008-04-09 15:30:00
# 16350  Merrill Lynch-ի վնասները հասել են 30 միլիարդ դ...  2008-04-10 14:28:00
# 16351  ՎՏԲ բանկը մտադիր է 670 մլն դոլար ուղղորդել ԱՊՀ...  2008-04-10 15:55:00
#
# ...

# %%
culture = pd.concat([cul1, cul2], axis=0)
culture["category"] = 1
culture
# Out:
#                                                   title                 date  \
# 0                       Ֆիլիպ Կիրկորովը ժամանել է Երևան  2021-09-17 16:03:00
# 1     «Կյանքիս մեծագույն պատիվներից էր». Հուզված Դեն...  2021-09-18 14:50:00
# 2     Մոսկվայում տեղի կունենան Առնո Բաբաջանյանի 100-...  2021-09-09 21:05:00
# 3     Իմացե՛ք ձեր իրավունքները. Ջոլին Amnesty Intern...  2021-09-03 21:34:00
# 4     Տեսողական խաբկանք. 18-ամյա ճապոնուհին զարմանահ...  2021-08-23 22:40:00
# ...                                                 ...                  ...
# 9870  Հայաստան է ժամանում ՌԴ ժողովրդական դերասան Վեն...  2008-04-15 16:02:00
# 9871  Հռոմի Պապն ամաչում է կաթոլիկ քահանաների պահված...  2008-04-15 19:21:00
# 9872       Նիկոլայ Կարաչենցևին հիվանդանոց են տեղափոխել   2008-04-07 12:06:00
# 9873  The Washington Post պարբերականը ստացել է վեց Պ...  2008-04-08 11:50:00
# 9874  Վիսբադենում բացվում է Սերգեյ Փարաջանովի լուսան...  2008-04-07 14:19:00
#
# ...

# %%
events = pd.concat([evnt1, evnt2, evnt3, evnt4, evnt5, evnt6, evnt7, evnt8, evnt9, evnt10, evnt11, evnt12, evnt13], axis=0)
events["category"] = 2
events
# Out:
#                                                    title                 date  \
# 0      Մինչ այս պահը պարզվել է Արցախում Ադրբեջանի զին...  2021-09-28 12:55:00
# 1      Առաջին անգամ Հայաստանում և Հարավկովկասյան տարա...  2021-09-28 13:03:00
# 2      55-ամյա քաղաքացին վիճաբանության ընթացքում խոհա...  2021-09-27 10:53:00
# 3      Ոստիկանության աշխատակցի Opel-ը, մի քանի պտույտ...  2021-09-27 23:19:00
# 4      Երևանի Գալինա Ստարովոյտովայի անվան թիվ 177 դպր...  2021-09-27 18:08:00
# ...                                                  ...                  ...
# 14978                    Պակիստանում զոհերի թիվն աճում է  2008-09-21 14:57:00
# 14979  Չինաստանում հրդեհի արդյունքում զոհվել են տասնյ...  2008-09-21 15:17:00
# 14980  Իրաքում ահաբեկչական գործողությունների հետևանքո...  2008-09-22 10:04:00
# 14981  Իսպանիան հայտնվել է ահաբեկչությունների կիզակետում  2008-09-22 10:14:00
# 14982  Չինաստանում ավելի քան 13 հազ. մանուկներ են տեղ...  2008-09-22 11:33:00
#
# ...

# %%
law["category"] = 3
politics["category"] = 4

# %%
press_digest = pd.concat([press1, press2], axis=0)
press_digest["category"] = 5
press_digest
# Out:
#                                                    title                 date  \
# 0      «Ժողովուրդ»․ Կառավարության անդամները կգնան խոր...  2021-09-24 09:16:00
# 1      «Հրապարակ»․ Հայաստանում, ինչպես Գերմանիայում. ...  2021-09-23 08:40:00
# 2      «Փաստ»․ Արթուր Ղազինյանի ջանքերով և մասնակցութ...  2021-09-23 08:50:00
# 3      «Հրապարակ»․ Հանրային պարսավանքի արդյունքում «գ...  2021-09-21 07:40:00
# 4      «Իրավունք». Արարատում իշխանության սցենարները փ...  2021-09-17 09:26:00
# ...                                                  ...                  ...
# 18767          «Ժամանակ». Թասիբ ունեցիր, հրաժարական տուր  2009-03-05 11:37:00
# 18768          «Առավոտ». Այլընտրանքը սոցիալական բունտն է  2009-03-06 11:13:00
# 18769               «Կապիտալ». Սրընթաց վայրէջքին պատրաստ  2009-03-06 11:14:00
# 18770        «Չորրորդ իշխանություն». Չի մերժի, բայց կտա՞  2009-03-06 11:16:00
# 18771                «Հայկական ժամանակ». Նա էլ հրաժարվեց  2009-03-06 11:17:00
#
# ...

# %%
sport = pd.concat([sport1, sport2, sport3, sport4, sport5, sport6], axis=0)
sport["category"] = 6
sport
# Out:
#                                                    title                 date  \
# 0      Արոնյանը հաղթել է Champions Chess Tour Finals-...  2021-09-27 11:20:00
# 1      Բարդ խաղ էր, բայց կարևորը հաղթեցինք. Մխիթարյան...  2021-09-24 09:49:00
# 2      Մեսսին իր արդյունավետությամբ ծածկում էր թիմի բ...  2021-09-22 13:16:00
# 3          Մեսսին կարող է բաց թողնել հերթական հանդիպումը  2021-09-24 12:07:00
# 4          Յուվենտուսը հրաժարվել է Պոգբային գնելու մտքից  2021-09-20 22:02:00
# ...                                                  ...                  ...
# 13296         Ռեհագելը համաձայնեց երկարաձգել պայմանագիրը  2008-03-28 12:47:00
# 13297  ATP-ի չեմպիոնական պայքար. Նալբանդյանը բարձրացա...  2008-03-24 16:41:00
# 13298  Իսպանացի կարգազանցը զրկեց հրեա երկրպագուին 12 ...  2008-03-24 17:00:00
# 13299  Ստալինին ու Եսենինին կարելի է տեսնել Ռումինիա ...  2008-03-24 17:09:00
# 13300  Հարավային ու Հյուսիսային Կորեաները կխաղան չեզո...  2008-03-24 17:20:00
#
# ...

# %%
other["category"] = 8
corona = pd.read_csv("data/corona.csv")
corona["category"] = 7

# %%
tert_am = pd.concat([business, culture, events, law, politics, press_digest, sport, corona, other])
tert_am
# Out:
#                                                    title                 date  \
# 0      «Գազպրոմը» 2021 թվականին ռեկորդային ծավալով գա...  2021-09-20 18:52:00
# 1      «Հայաստան 2020» ծրագրի նախաձեռնողները ներկայաց...  2021-09-20 19:26:00
# 2      Երևանում կասեցվել է հացի արտադրամասի գործունեո...  2021-09-13 12:06:00
# 3             Եվրոպայում գազի գինը նոր ռեկորդ է սահմանել  2021-09-13 12:11:00
# 4      Ալյումինի գինը նվազել է, պղնձի գինն` աճել. գու...  2021-09-04 11:05:00
# ...                                                  ...                  ...
# 11813  «Գրեմմի»-ի հնգակի մրցանակակիր The Swingles խմբ...  2019-04-30 12:43:00
# 11814  «Կազմակերպիչն արտիստներին չէր վճարել, սակայն կ...  2019-05-22 14:00:00
# 11815  Բեմական կյանքի 60 տարիները․ Ռոզի Արմենը ելույթ...  2019-05-28 11:49:00
# 11816  Deep Purple-ի վոկալիստ Իէն Գիլանը և Black Sabb...  2019-06-05 15:16:00
# 11817  Իէն Գիլանի ու Թոնի Այոմիի այցը Գյումրի. տնակնե...  2019-06-07 14:07:00
#
# ...

# %%
np.min(tert_am.date)
# Out:
# '2008-02-04 18:45:00'

# %%
np.max(tert_am.date)
# Out:
# '2021-09-29 19:02:00'

# %%
#tert_am.to_csv("data/tert_am.csv", index=False)
tert_am.title
# Out:
# 0        «Գազպրոմը» 2021 թվականին ռեկորդային ծավալով գա...
# 1        «Հայաստան 2020» ծրագրի նախաձեռնողները ներկայաց...
# 2        Երևանում կասեցվել է հացի արտադրամասի գործունեո...
# 3               Եվրոպայում գազի գինը նոր ռեկորդ է սահմանել
# 4        Ալյումինի գինը նվազել է, պղնձի գինն` աճել. գու...
#                                ...
# 11813    «Գրեմմի»-ի հնգակի մրցանակակիր The Swingles խմբ...
# 11814    «Կազմակերպիչն արտիստներին չէր վճարել, սակայն կ...
# 11815    Բեմական կյանքի 60 տարիները․ Ռոզի Արմենը ելույթ...
# 11816    Deep Purple-ի վոկալիստ Իէն Գիլանը և Black Sabb...
# 11817    Իէն Գիլանի ու Թոնի Այոմիի այցը Գյումրի. տնակնե...
# Name: title, Length: 414432, dtype: object

# %%
arm_letters = list("ԷԹՓՁՋՐՉՃԺԾՇԽՊՕԻԸՏՌԵՈՔԱՍԴՖԳՀՅԿԼՆՄԲՑՎԶՂ") + ["ՈՒ"]
len(arm_letters)
# Out:
# 38

# %%
NE_freq = tert_am.title.str.extractall("([ԷԹՓՁՋՐՉՃԺԾՇԽՊՕԻԸՏՌԵՈՔԱՍԴՖԳՀՅԿԼՆՄԲՑՎԶՂ]\w+)").value_counts()
NE_freq
# Out:
# ՀՀ                   13748
# ԱՄՆ                  13281
# Հայաստանի             8387
# Հրապարակ              7819
# Ժողովուրդ             7464
#                      ...
# Կուրորտաբանության        1
# Կուրություն              1
# Կուրս                    1
# Կուրսկայա                1
# Ֆրուտ                    1
# Length: 64174, dtype: int64

# %%
NEF = pd.DataFrame(NE_freq)

# %%
NEF = NEF.rename_axis(["name"])

# %%
NEF = NEF.reset_index()
NEF
# Out:
#                     name      0
# 0                     ՀՀ  13748
# 1                    ԱՄՆ  13281
# 2              Հայաստանի   8387
# 3               Հրապարակ   7819
# 4              Ժողովուրդ   7464
# ...                  ...    ...
# 64169  Կուրորտաբանության      1
# 64170        Կուրություն      1
# 64171              Կուրս      1
# 64172          Կուրսկայա      1
# 64173              Ֆրուտ      1
#
# [64174 rows x 2 columns]

# %%
np.sum(NEF[NEF.name.str.contains("Ռուս")].iloc[:, 1])
# Out:
# 10185

# %%
np.sum(NEF[NEF.name.str.contains("Հայ")].iloc[:, 1])
# Out:
# 38234

# %%
np.sum(NEF[NEF.name.str.contains("Ֆրանս")].iloc[:, 1])
# Out:
# 4096

# %%
np.sum(NEF[NEF.name.str.contains("Գերման")].iloc[:, 1])
# Out:
# 3123

# %%
np.sum(NEF[NEF.name.str.contains("Չին")].iloc[:, 1])
# Out:
# 3796

# %%
np.sum(NEF[NEF.name.str.contains("Նիկոլ")].iloc[:, 1])
# Out:
# 5063

# %%
np.sum(NEF[NEF.name.str.contains("Սերժ")].iloc[:, 1])
# Out:
# 2773

# %%
np.sum(NEF[NEF.name.str.contains("Ծառուկյան")].iloc[:, 1])
# Out:
# 1249

# %%
np.sum(NEF[NEF.name.str.contains("Քոչարյան")].iloc[:, 1])
# Out:
# 1898

# %%
53.95 /21.11 # Nikol vs Kocharyan votes last election
# Out:
# 2.5556608242539083

# %%
np.sum(NEF[NEF.name.str.contains("Նիկոլ")].iloc[:, 1]) / np.sum(NEF[NEF.name.str.contains("Քոչարյան")].iloc[:, 1])
# Out:
# 2.66754478398314

# %% [markdown]
# Wow

# %%
53.95 / 5.22 # Nikol vs Vanetsyan votes last election
# Out:
# 10.335249042145595

# %%
np.sum(NEF[NEF.name.str.contains("Նիկոլ")].iloc[:, 1]) / np.sum(NEF[NEF.name.str.contains("Վանեցյան")].iloc[:, 1])
# Out:
# 9.341328413284133

# %%
np.sum(NEF[NEF.name.str.contains("Ադրբեջ")].iloc[:, 1])
# Out:
# 7825

# %%
tert_am[tert_am.content.str.contains("Ադրբեջ").fillna(False)].category.value_counts()
# Out:
# 2    13646
# 4     4643
# 5     1734
# 0     1052
# 6      896
# 3      426
# 1      290
# 7      185
# 8      125
# Name: category, dtype: int64

# %%
tert_am.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 414432 entries, 0 to 11817
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   title     414432 non-null  object
#  1   date      414432 non-null  object
#  2   content   413325 non-null  object
#  3   category  414432 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 15.8+ MB

# %%
tert_am["date"] = pd.to_datetime(tert_am["date"])

# %%
np.sum(tert_am.content.str.contains(" ա ", case=False))
# Out:
# 3338

# %%
np.sum(tert_am.content.str.contains(" է ", case=False))
# Out:
# 399732

# %%
np.sum((tert_am.content.str.contains(" է ", case=False)) | tert_am.content.str.contains(" ա ", case=False)) - np.sum(tert_am.content.str.contains(" է ", case=False))
# Out:
# 152

# %%
np.sum(tert_am.content.str.contains("կրոն", case=False) | tert_am.content.str.contains("եկեղեցի", case=False) | tert_am.content.str.contains("քրիստոն", case=False) | tert_am.content.str.contains("Մայր Աթոռ", case=False))
# Out:
# 9171

# %%
np.sum(tert_am.content.str.contains("հայրենիք", case=False) | tert_am.content.str.contains("հայաստան", case=False) | tert_am.content.str.contains(" հող ", case=False))
# Out:
# 103326

# %%
np.sum(tert_am.content.str.contains("լեզու", case=False) | tert_am.content.str.contains("գիրք", case=False) | tert_am.content.str.contains(" մշակու", case=False) | tert_am.content.str.contains("դպրոց", case=False) | tert_am.content.str.contains("հայերեն", case=False))
# Out:
# 29127

# %%
np.sum(tert_am.content.str.contains("ԱՄՆ", case=False) | tert_am.content.str.contains("ամերիկ", case=False))
# Out:
# 78234

# %%
np.sum(tert_am.content.str.contains("Ռուս", case=False))
# Out:
# 74837

# %%
np.sum(tert_am.content.str.contains("Ադրբեջ", case=False))
# Out:
# 27302

# %%
np.sum(tert_am.content.str.contains("Հայ", case=False))
# Out:
# 306526

# %%
np.sum(tert_am.content.str.contains("Թուրք", case=False))
# Out:
# 25979

# %%
np.sum(tert_am.content.str.contains("ֆրանս", case=False))
# Out:
# 22972

# %%
np.sum(tert_am.content.str.contains("Գերման", case=False))
# Out:
# 18661

# %%
np.sum(tert_am.content.str.contains("Չին") | tert_am.content.str.contains("չին"))
# Out:
# 33163

# %%
np.sum(tert_am.content.str.contains("եվրոպ") | tert_am.content.str.contains("Եվրոպ"))
# Out:
# 28597

# %%
np.sum(tert_am.content.str.contains("Ասիա") | tert_am.content.str.contains("ասիա"))
# Out:
# 6521

# %%
np.sum(tert_am.content.str.contains("վրաստան", case=False) | tert_am.content.str.contains("վրաց", case=False))
# Out:
# 13335

# %%
np.sum(tert_am.content.str.contains("իրան") | tert_am.content.str.contains("պարս"))
# Out:
# 9131

# %%
# dfs = [business, culture, events, law, politics, press_digest, sport, corona, other]
# df_names = ["business", "culture", "events", "law", "politics", "press_digest", "sport", "corona", "other"]
# for i in range(len(dfs)):
#     dfs[i].to_csv(f"data/aggr/{df_names[i]}.csv", index = False)

# %%
np.sum(tert_am.content.str.contains(" գ ", case=False))
# Out:
# 178

# %%
np.sum(tert_am.content.str.contains(" եկ ", case=False))
# Out:
# 12

# %%
np.sum(tert_am.content.str.contains(" մը ", case=False))
# Out:
# 50

# %%
np.sum(tert_am.content.str.contains(" արցախ ", case=False))
# Out:
# 988

# %%
np.sum(tert_am.content.str.contains(" ղարաբաղ ", case=False))
# Out:
# 387

# %%
np.sum(tert_am.content.str.contains(" քելբաջար ", case=False))
# Out:
# 6

# %%
np.sum(tert_am.content.str.contains(" քարվաճառ ", case=False))
# Out:
# 72

# %%
np.sum(tert_am.content.str.contains(" աղդամ ", case=False))
# Out:
# 15

# %%
np.sum(tert_am.content.str.contains(" ակնա ", case=False))
# Out:
# 26

# %%
np.sum(tert_am.content.str.contains(" էրզրում ", case=False))
# Out:
# 28

# %%
np.sum(tert_am.content.str.contains(" կարին ", case=False))
# Out:
# 151

# %%
np.sum(tert_am.content.str.contains(" խաղաղ", case=False))
# Out:
# 17276

# %%
np.sum(tert_am.content.str.contains(" պատերազմ ", case=False) | tert_am.content.str.contains(" թշնամ ", case=False) | tert_am.content.str.contains(" մարտեր ", case=False) | tert_am.content.str.contains(" մարտեր ", case=False))
# Out:
# 2489

# %%
np.sum(tert_am.content.str.contains(" ուրախ", case=False) | tert_am.content.str.contains(" տոն", case=False))
# Out:
# 24446

# %%
np.sum(tert_am.content.str.contains(" տխուր", case=False) | tert_am.content.str.contains(" հիշատակ", case=False) | tert_am.content.str.contains(" սուգ", case=False) | tert_am.content.str.contains(" սգո", case=False) | tert_am.content.str.contains(" տխր", case=False))
# Out:
# 8493

# %%
np.sum(tert_am.content.str.contains("hերոս", case=False))
# Out:
# 3

# %%
np.sum(tert_am.content.str.contains("դավաճ", case=False))
# Out:
# 3101

# %%
np.sum(tert_am.content.str.contains("նախկին", case=False))
# Out:
# 45384

# %%
np.sum(tert_am.content.str.contains("ներկա", case=False))
# Out:
# 129028

# %%
np.sum(tert_am.content.str.contains("բարելավ", case=False))
# Out:
# 6053

# %%
np.sum(tert_am.content.str.contains("վատթարա", case=False))
# Out:
# 1817

# %%
np.sum(tert_am.content.str.contains("միօրինակ", case=False) | tert_am.content.str.contains("միանման", case=False))
# Out:
# 222

# %%
np.sum(tert_am.content.str.contains("տարօրինակ", case=False) | tert_am.content.str.contains("բազմազան", case=False)| tert_am.content.str.contains("բազում", case=False) )
# Out:
# 4781
